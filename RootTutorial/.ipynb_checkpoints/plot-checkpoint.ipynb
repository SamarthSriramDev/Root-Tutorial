// %%
TFile *file = new TFile("output.root", "Read");//We are reading out from the root file in this case 

TH1F *hist = (TH1F*)file->Get("hist");

TCanvas *c1 = new TCanvas();

hist->Draw();
c1->Draw();
