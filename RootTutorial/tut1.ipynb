// %%
TH1F *hist = new TH1F("hist","Histogram",100,0,100);
    
hist->Fill(10);
hist->Fill(90);
hist->GetXaxis()->SetTitle("Age");
hist->GetYaxis()->SetTitle("Salary");

TCanvas *c1 = new TCanvas();
    
hist->Draw();

c1->Draw();
